# %%
# !pip install git+https://github.com/openai/whisper
# !sudo apt update && sudo apt install ffmpeg

# %%
# !whisper -h

# %%
# !whisper "redrum.mp3" --model medium --language {'vi'}
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:08<00:00, 180MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:05.000]  Đôi khi tôi vẫn nhấn nhớ dẫu đã không còn kịp giờ
# [00:05.000 --> 00:09.000]  Đôi khi tôi đến sớm hơn
# [00:09.000 --> 00:14.000]  Thâm tâm tôi muốn bắt em suy tư khi ngồi đợi chờ
# [00:14.000 --> 00:18.000]  Nhưng tim tôi vẫn biết hơn
# [00:18.000 --> 00:24.000]  Vì thực tế dẫu em có vấn tâm thì tôi vẫn đến sau
# [00:24.000 --> 00:28.000]  Mấy ai mới đối cầu thành gia yêu mến nhau
# [00:28.000 --> 00:33.000]  Lòng thờ biết những tin nhắn không xem hoặc ngưng trong giỡ gian
# [00:33.000 --> 00:38.000]  Chính khi ấy em hồn bạn trai môi thở than
# [00:38.000 --> 00:43.000]  Người ơi, có ai biết em cũng nếu anh không chờ đưa dùm
# [00:43.000 --> 00:47.000]  Còn tim em vẫn đơn côi
# ...

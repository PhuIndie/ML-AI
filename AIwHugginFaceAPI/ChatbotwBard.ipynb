# %% [markdown]
# #Import Google Bard

# %%
#it takes my time af
# !pip install --upgrade pip

# %%
# !pip install google-auth google-cloud-core --upgrade

# %%
# !pip install bardapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 88.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=59f558bf6d2260eae7f99601d4785a5c510d3044c424d3056a37741f102dd110
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# ...

# %%
from bardapi import Bard
import os
import time

# %%
os.environ['_BARD_API_KEY']="aQj2LdZ0BdX0sQBJaqM-5dmpFEmJ_1Mvch2b9hTd_fmt8R-qH2rTeyrXwjwS5O65ml2_sQ."

# %%
#Test API connection
input_text = "What is the current status of Ashes Series 2023"
print(Bard().get_answer(input_text)['content'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-0cf3a7df78df> in <cell line: 3>()
#       1 #Test API connection
#       2 input_text = "What is the current status of Ashes Series 2023"
# ----> 3 print(Bard().get_answer(input_text)['content'])
#
# /usr/local/lib/python3.10/dist-packages/bardapi/core.py in __init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser)
#      53         self.choice_id = ""
#      54         self.session = self._get_session(session)
# ---> 55         self.SNlM0e = self._get_snim0e()
#      56         self.language = language or os.getenv("_BARD_API_LANG")
#      57         self.run_code = run_code
#
# /usr/local/lib/python3.10/dist-packages/bardapi/core.py in _get_snim0e(self)
#     126         snim0e = re.search(r"SNlM0e\":\"(.*?)\"", resp.text)
# ...
